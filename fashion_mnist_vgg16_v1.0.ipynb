# %%
# Base libs and modules import

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LeakyReLU, BatchNormalization

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices()[2])
# Out:
# name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4954920064
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11630154333005942809
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"

# %%
# Distribution of the dataset into training and test samples

# %%
(X_train, label_train), (X_test, label_test) = fashion_mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
# Convert the images into 3 channels

# %%
X_train = np.dstack([X_train] * 3)
X_test = np.dstack([X_test] * 3)

# %%
X_train = X_train.reshape(-1, 28, 28, 3)
X_test = X_test.reshape(-1, 28, 28, 3)
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28, 3), (10000, 28, 28, 3))

# %%
# Resize the images into 48x48 px as required by VGG16

# %%
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img

# %%
X_train = np.asarray([img_to_array(array_to_img(im, scale=False).resize((48,48))) for im in X_train])
X_test = np.asarray([img_to_array(array_to_img(im, scale=False).resize((48,48))) for im in X_test])

# %%
# Normalizatoin dataset

# %%
X_train = X_train.astype("float32") / 255

X_test = X_test.astype("float32") / 255

# %%
# Intro train dataset

# %%
label_name = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
plt.figure(figsize=(15, 15), facecolor='HoneyDew')
for i in range(20):
    plt.subplot(5,4,i+1)
    plt.imshow(X_train[i])
    plt.xticks([])
    plt.yticks([])
    plt.colorbar()
    plt.xlabel(label_name[label_train[i]])

# %%
# VGG16 model

# %%
from tensorflow.keras.applications.vgg16 import VGG16

# %%
vgg16_base = VGG16(weights="imagenet", include_top=False, input_shape=(48, 48, 3))
vgg16_base.trainable = True
set_trainable = False

layer_train_lst = ['block5_conv1', 'block5_conv2', 'block5_conv3']

for layer in vgg16_base.layers:
    if layer.name in layer_train_lst:
        set_trainable = True
    elif set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
vgg16_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 48, 48, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 48, 48, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 48, 48, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 24, 24, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 24, 24, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 24, 24, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 12, 12, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 12, 12, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 12, 12, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 12, 12, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 6, 6, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 6, 6, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 3, 3, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 3, 3, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 3, 3, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 7,079,424
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
# Create neural network model with VGG16

# %%
model = keras.Sequential([
    vgg16_base,    
    keras.layers.Flatten(),
    keras.layers.Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(128, activation="relu", kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(32, activation="sigmoid", kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dense(10, activation="softmax", name='out_layer')
])

# %%
# Compile model NN

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 1, 1, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                4128
# _________________________________________________________________
# out_layer (Dense)            (None, 10)                330
# =================================================================
# Total params: 15,047,466
# Trainable params: 7,412,202
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
# Learning model NN

# %%
batch_size = 256
epochs = 30
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)

# %%
history=model.fit(
    X_train,
    label_train,
    validation_split=0.2,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=early_stop
)
# Out:
# Epoch 1/30
# 188/188 [==============================] - 18s 97ms/step - loss: 1.2074 - accuracy: 0.7558 - val_loss: 0.8501 - val_accuracy: 0.8122
# Epoch 2/30
# 188/188 [==============================] - 17s 89ms/step - loss: 0.7009 - accuracy: 0.8383 - val_loss: 0.6014 - val_accuracy: 0.8427
# Epoch 3/30
# 188/188 [==============================] - 17s 89ms/step - loss: 0.5367 - accuracy: 0.8601 - val_loss: 0.4925 - val_accuracy: 0.8612
# Epoch 4/30
# 188/188 [==============================] - 17s 90ms/step - loss: 0.4471 - accuracy: 0.8754 - val_loss: 0.4699 - val_accuracy: 0.8549
# Epoch 5/30
# 188/188 [==============================] - 17s 89ms/step - loss: 0.3905 - accuracy: 0.8873 - val_loss: 0.4040 - val_accuracy: 0.8789
# Epoch 6/30
# 188/188 [==============================] - 17s 91ms/step - loss: 0.3505 - accuracy: 0.8955 - val_loss: 0.3812 - val_accuracy: 0.8825
# Epoch 7/30
# 188/188 [==============================] - 17s 90ms/step - loss: 0.3272 - accuracy: 0.8990 - val_loss: 0.3726 - val_accuracy: 0.8865
# Epoch 8/30
# 188/188 [==============================] - 17s 89ms/step - loss: 0.3090 - accuracy: 0.9033 - val_loss: 0.3645 - val_accuracy: 0.8875
# Epoch 9/30
# 188/188 [==============================] - 16s 88ms/step - loss: 0.2883 - accuracy: 0.9092 - val_loss: 0.3534 - val_accuracy: 0.8907
# Epoch 10/30
# 188/188 [==============================] - 17s 88ms/step - loss: 0.2729 - accuracy: 0.9130 - val_loss: 0.3856 - val_accuracy: 0.8768
# Epoch 11/30
# 188/188 [==============================] - 17s 88ms/step - loss: 0.2588 - accuracy: 0.9171 - val_loss: 0.3529 - val_accuracy: 0.8898
# Epoch 12/30
# 188/188 [==============================] - 16s 87ms/step - loss: 0.2509 - accuracy: 0.9213 - val_loss: 0.3611 - val_accuracy: 0.8915
# Epoch 13/30
# 188/188 [==============================] - 16s 88ms/step - loss: 0.2359 - accuracy: 0.9263 - val_loss: 0.3383 - val_accuracy: 0.8949
# Epoch 14/30
# 188/188 [==============================] - 16s 88ms/step - loss: 0.2242 - accuracy: 0.9289 - val_loss: 0.3475 - val_accuracy: 0.8948
# Epoch 15/30
# 188/188 [==============================] - 16s 88ms/step - loss: 0.2115 - accuracy: 0.9334 - val_loss: 0.3398 - val_accuracy: 0.8953

# %%
# Model results

# %%
results = model.evaluate(X_test, label_test)
print(f'Model Loss: {round(results[0], 3)} \nModel Accuracy: {round(results[1], 3)}')
# Out:
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3544 - accuracy: 0.8907
# Model Loss: 0.354
# Model Accuracy: 0.891

# %%
# Plot train and validation data

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 9))


axes[0].set_title('Train metrics Loss & Val_Loss')
axes[0].plot(history.history['loss'], label='Loss', color='SteelBlue')
axes[0].plot(history.history['val_loss'], label='Val_loss', marker='o', linestyle='--', color='SteelBlue')
axes[0].legend()

axes[1].set_title('Train metrics Accuracy & Val_Accuracy')
axes[1].plot(history.history['accuracy'], label='Accuracy', color='DarkOrange')
axes[1].plot(history.history['val_accuracy'], label='Val_Accuracy', marker='o', linestyle='--', color='DarkOrange')
axes[1].legend()

plt.show()

# %%
# Predict model NN

# %%
predict=model.predict(X_test)

# %%
random_indexes = np.random.choice(len(X_test), size=28, replace=False)

plt.figure(figsize=(13, 15), facecolor='HoneyDew')

for i in range(len(random_indexes)):
    
    index = random_indexes[i]
    
    pred_label = label_name[np.argmax(predict[index])]
    true_label = label_name[label_test[index]]
    
    if pred_label == true_label:
        color = "DarkBlue"
    else:
        color = "FireBrick"
    
    plt.subplot(7,4,i+1)
    plt.imshow(X_test[index])
    plt.xticks([])
    plt.yticks([])
    plt.colorbar()
    
    plt.xlabel("{} [{}]".format(true_label, pred_label), color=color)

# %%
# Confusion matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
pred_label_enc = model.predict(X_test)

pred_label = [np.argmax(i) for i in pred_label_enc]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(confusion_matrix(label_test, pred_label), annot=True, 
            cbar=False, fmt='1d', cmap='Blues', ax=ax)
ax.set_title('Confusion Matrix', fontsize=16)
ax.set_xlabel('Predict label')
ax.set_ylabel('True label')
ax.set_xticklabels([label for label in label_name], rotation=45)
ax.set_yticklabels(([label for label in label_name]), rotation=0)
plt.show()
